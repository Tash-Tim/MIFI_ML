# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv', sep=',')
melb_df['Date'] = pd.to_datetime(melb_df['Date'])

exclude_colu = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_uniq_cnt = 150
for i_col in melb_df.columns:
    if melb_df[i_col].nunique() < (max_uniq_cnt) and i_col not in exclude_colu:
        melb_df[i_col] = melb_df[i_col].astype('category')

melb_df
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 0        Abbotsford      2  house  1480000.0      S    Biggin 2016-03-12
# 1        Abbotsford      2  house  1035000.0      S    Biggin 2016-04-02
# 2        Abbotsford      3  house  1465000.0     SP    Biggin 2017-04-03
# 3        Abbotsford      3  house   850000.0     PI    Biggin 2017-04-03
# 4        Abbotsford      4  house  1600000.0     VB    Nelson 2016-04-06
# ...             ...    ...    ...        ...    ...       ...        ...
# 13575         other      4  house  1245000.0      S     Barry 2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams 2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine 2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney 2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %% [markdown]
# # Метод groupby()

# %% [markdown]
# ## Группировка данных по одному критерию с одной агрегацией

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\2774055988.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\2099806448.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
# Агрегирующие методы можно применять только к интересующему нас столбцу. 
# Например, давайте сравним средние цены на объекты в зависимости от их типа:

melb_df.groupby(by='Type')['Price'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\2691174445.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
# Какие регионы (Regionname) наиболее удалены от центра Мельбурна
# найдём минимальное значение расстояния от центра города до объекта в зависимости от его региона. 
# Результат отсортируем по убыванию расстояния

melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\1536581337.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %% [markdown]
# ## Группировка данных по одному критерию с несколькими агрегациями

# %%
# построим таблицу для анализа продаж по месяцам. Для этого найдём количество продаж, а также среднее и максимальное значения 
# цен объектов недвижимости (Price), сгруппированных по номеру месяца продажи (MonthSale). 
# Результат отсортируем по количеству продаж в порядке убывания:

melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
    ).sort_values(by='count', ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\3644072940.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
# Если вам нужна полная информация обо всех основных статистических характеристиках внутри каждой группы, вы можете в
# оспользоваться методом agg(), передав в качестве его параметра строку 'describe':

melb_df.groupby('MonthSale')['Price'].agg('describe').sort_values(by='count', ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\1748956809.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe').sort_values(by='count', ascending=False)
#             count          mean            std       min       25%        50%  \
# MonthSale
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# ...

# %%
# Мы можем вычислить число уникальных риелторских компаний в зависимости от региона, чтобы понять, в каких регионах 
# конкуренция на рынке недвижимости меньше. Это можно сделать, передав в параметр метода agg() строку 'nunique'.
# Передадим дополнительно встроенную функцию set, чтобы получить множество из агентств недвижимости, которые работают в каждом из регионов:

melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set]).sort_values(by='nunique', ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\493475896.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set]).sort_values(by='nunique', ascending=False)
#                             nunique  \
# Regionname
# Northern Metropolitan            40
# Southern Metropolitan            38
# Western Metropolitan             34
# Eastern Metropolitan             26
# South-Eastern Metropolitan       25
# Eastern Victoria                 11
# Northern Victoria                11
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Northern Metropolitan       {HAR, Stockdale, Eview, Collins, Fletchers, Je...
# ...

# %%
# Сгруппируем данные по признаку количества комнат и найдите среднюю цену объектов недвижимости в каждой группе. 

melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
# Какой регион имеет наименьшее стандартное отклонение (.std()) по географической широте (Lattitude)?
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\2833887339.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
# Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?

from_date = melb_df['Date']>'2017-05-01'
to_date = melb_df['Date']<='2017-09-01'
melb_df[from_date & to_date].groupby('SellerG')['Price'].sum().sort_values()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10724\1178927727.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[from_date & to_date].groupby('SellerG')['Price'].sum().sort_values()
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# ...
