# %% [markdown]
# # Вывод первых и последних строк

# %% [markdown]
# - Для этого у DataFrame есть методы head() и tail(), которые возвращают n первых и n последних строк таблицы соответственно (по умолчанию n = 5).

# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0        Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0
# 1        Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 2        Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 3        Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0
# 4        Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# ...         ...         ...       ...  ...  ...       ...           ...
# 13575     Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# 13576  Williams  26/08/2017       6.8  ...  2.0     333.0         133.0
# 13577     Raine  26/08/2017       6.8  ...  4.0     436.0         126.0
# 13578   Sweeney  26/08/2017       6.8  ...  5.0     866.0         157.0
# 13579   Village  26/08/2017       6.3  ...  1.0     362.0         112.0
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude  \
# 0         1970.0        Yarra  -37.79960   144.99840
# 1         1900.0        Yarra  -37.80790   144.99340
# 2         1900.0        Yarra  -37.80930   144.99440
# 3         1970.0        Yarra  -37.79690   144.99690
# 4         2014.0        Yarra  -37.80720   144.99410
# ...          ...          ...        ...         ...
# 13575     1981.0          NaN  -37.90562   145.16761
# 13576     1995.0          NaN  -37.85927   144.87904
# 13577     1997.0          NaN  -37.85274   144.88738
# 13578     1920.0          NaN  -37.85908   144.89299
# 13579     1920.0          NaN  -37.81188   144.88449
#
#                        Regionname  Propertycount           Coordinates
# 0           Northern Metropolitan         4019.0    -37.7996, 144.9984
# 1           Northern Metropolitan         4019.0    -37.8079, 144.9934
# 2           Northern Metropolitan         4019.0    -37.8093, 144.9944
# 3           Northern Metropolitan         4019.0    -37.7969, 144.9969
# 4           Northern Metropolitan         4019.0    -37.8072, 144.9941
# ...                           ...            ...                   ...
# 13575  South-Eastern Metropolitan         7392.0  -37.90562, 145.16761
# 13576        Western Metropolitan         6380.0  -37.85927, 144.87904
# 13577        Western Metropolitan         6380.0  -37.85274, 144.88738
# 13578        Western Metropolitan         6380.0  -37.85908, 144.89299
# 13579        Western Metropolitan         6543.0  -37.81188, 144.88449
#
# [13580 rows x 23 columns]

# %%
display(melb_data.head())
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0        Yarra   -37.7996    144.9984  Northern Metropolitan         4019.0
# 1        Yarra   -37.8079    144.9934  Northern Metropolitan         4019.0
# 2        Yarra   -37.8093    144.9944  Northern Metropolitan         4019.0
# 3        Yarra   -37.7969    144.9969  Northern Metropolitan         4019.0
# 4        Yarra   -37.8072    144.9941  Northern Metropolitan         4019.0
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %%
display(melb_data.tail())
# Out:
#        index         Suburb        Address  Rooms Type      Price Method  \
# 13575  13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 13575     Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# 13576  Williams  26/08/2017       6.8  ...  2.0     333.0         133.0
# 13577     Raine  26/08/2017       6.8  ...  4.0     436.0         126.0
# 13578   Sweeney  26/08/2017       6.8  ...  5.0     866.0         157.0
# 13579   Village  26/08/2017       6.3  ...  1.0     362.0         112.0
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude  \
# 13575     1981.0          NaN  -37.90562   145.16761
# 13576     1995.0          NaN  -37.85927   144.87904
# 13577     1997.0          NaN  -37.85274   144.88738
# 13578     1920.0          NaN  -37.85908   144.89299
# 13579     1920.0          NaN  -37.81188   144.88449
#
#                        Regionname  Propertycount           Coordinates
# 13575  South-Eastern Metropolitan         7392.0  -37.90562, 145.16761
# 13576        Western Metropolitan         6380.0  -37.85927, 144.87904
# 13577        Western Metropolitan         6380.0  -37.85274, 144.88738
# 13578        Western Metropolitan         6380.0  -37.85908, 144.89299
# 13579        Western Metropolitan         6543.0  -37.81188, 144.88449
#
# [5 rows x 23 columns]

# %% [markdown]
# # Размерность таблицы

# %%
melb_data.shape
# Out:
# (13580, 23)

# %% [markdown]
# # Получение информации о столбцах

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  float64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(11), int64(3), object(9)
# memory usage: 2.4+ MB

# %% [markdown]
# # Изменение типа данных в столбце

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')

melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  int64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(6), int64(8), object(9)
# memory usage: 2.4+ MB

# %%
cont = 0
for i_column in melb_data.columns:
    if melb_data[i_column].dtype == 'int64':
        print(i_column)
        cont += 1 
print(cont)
# Out:
# index
# Rooms
# Postcode
# Bedroom
# Bathroom
# Car
# YearBuilt
# Propertycount
# 8

# %% [markdown]
# # Получение описательной статистики

# %% [markdown]
# >  Часто при работе с таблицей нужно быстро посмотреть на основные статистические свойства её столбцов. Для этого можно воспользоваться методом DataFrame describe().

# %% [markdown]
# По умолчанию метод работает с числовыми (int64 и float64) столбцами и показывает число непустых значений (count), среднее (mean), стандартное отклонение (std), минимальное значение (min),  квантили уровней 0.25, 0.5 (медиана) и 0.75 (25%, 50%, 75%) и максимальное значение (max) для каждого столбца исходной таблицы.

# %%
melb_data.describe().loc[:,['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include='object')
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %% [markdown]
# - количество непустых строк (count);
# - количество уникальных значений (unique);
# - самое частое значение — мода —  (top);
# - частота — объём использования — этого значения (freq) для каждого столбца типа object исходной таблицы.

# %% [markdown]
# # Получение частоты уникальных значений в столбце

# %% [markdown]
# - Для того чтобы определить, сколько раз в столбце повторяется каждый из вариантов значений (т.е. найти частоту для каждого уникального знания), используется метод value_counts().

# %%
melb_data['Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Regionname
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: proportion, dtype: float64

# %%
melb_data['Type'].value_counts(normalize=True)*100
# Out:
# Type
# h    69.580265
# u    22.216495
# t     8.203240
# Name: proportion, dtype: float64

# %%
melb_data.value_counts(normalize=True)
# Out:
# index  Suburb        Address            Rooms  Type  Price      Method  SellerG   Date        Distance  Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  CouncilArea    Lattitude  Longtitude  Regionname             Propertycount  Coordinates
# 0      Abbotsford    85 Turner St       2      h     1480000.0  S       Biggin    3/12/2016   2.5       3067      2        1         1    202.0     126.0         1970       Yarra          -37.79960  144.99840   Northern Metropolitan  4019           -37.7996, 144.9984      0.000082
# 8145   Newport       16 Thorpe St       3      h     1100000.0  PI      Sweeney   29/04/2017  8.4       3015      3        1         6    761.0     126.0         1970       Hobsons Bay    -37.84640  144.86500   Western Metropolitan   5498           -37.8464, 144.865       0.000082
# 8136   Newport       33 Bunbury St      1      h     1700000.0  S       Jas       20/05/2017  8.4       3015      1        1         0    622.0     126.0         1970       Hobsons Bay    -37.84970  144.89030   Western Metropolitan   5498           -37.8497, 144.8903      0.000082
# 8137   Newport       139 Blackshaws Rd  4      h     956000.0   S       Sweeney   22/04/2017  8.4       3015      4        2         4    540.0     113.0         1970       Hobsons Bay    -37.83390  144.87160   Western Metropolitan   5498           -37.8339, 144.8716      0.000082
# 8138   Newport       21 Junction St     2      h     1215000.0  SP      Jas       22/04/2017  8.4       3015      2        1         2    482.0     126.0         1970       Hobsons Bay    -37.83580  144.88030   Western Metropolitan   5498           -37.8358, 144.8803      0.000082
#                                                                                                                                                                                                                                                                                    ...
# 4072   Moonee Ponds  3/16 Turner St     2      u     550000.0   VB      Woodards  10/09/2016  6.9       3039      2        1         1    0.0       85.0          1990       Moonee Valley  -37.76170  144.93670   Western Metropolitan   6232           -37.7617, 144.9367      0.000082
# 4073   Moonee Ponds  50 Wilson St       4      h     1211000.0  S       Nelson    10/09/2016  6.9       3039      3        1         3    477.0     146.0         1910       Moonee Valley  -37.76320  144.92920   Western Metropolitan   6232           -37.7632, 144.9292      0.000082
# 4074   Moonee Ponds  12 Chaucer St      5      h     2405000.0  S       Nelson    10/12/2016  6.9       3039      5        2         1    0.0       126.0         1970       Moonee Valley  -37.76960  144.92270   Western Metropolitan   6232           -37.7696, 144.9227      0.000082
# 4075   Moonee Ponds  35 Eglinton St     4      h     1395000.0  PI      Brad      10/12/2016  6.9       3039      4        1         2    603.0     126.0         1970       Moonee Valley  -37.76920  144.91700   Western Metropolitan   6232           -37.7692, 144.917       0.000082
# 12212  Yarraville    54 Pentland Pde    6      h     2450000.0  VB      Village   29/07/2017  6.3       3013      6        3         2    1087.0    388.5         1920       Maribyrnong    -37.81038  144.89389   Western Metropolitan   6543           -37.81038, 144.89389    0.000082
# Name: proportion, Length: 12211, dtype: float64
