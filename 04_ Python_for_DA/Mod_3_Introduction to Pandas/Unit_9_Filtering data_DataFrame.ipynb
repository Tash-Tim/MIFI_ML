# %% [markdown]
# - Под __фильтрацией в DataFrame__ подразумевается получение новой таблицы путём вырезания строк, не удовлетворяющих поставленному условию.

# %% [markdown]
# # Классический способ фильтрации Маска.

# %% [markdown]
# - Маской называется Series, которая состоит из булевых значений, при этом значения True соответствуют тем индексам, для которых заданное условие выполняется, в противном случае ставится значение False

# %%
import pandas as pd

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')

# %%
mask = melb_data['Price'] > 2000000
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool

# %%
melb_data[mask].head()
# Out:
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...  0.0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...  1.0     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...  1.0     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...  1.0     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...  1.0     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
melb_data[mask].tail()
# Out:
#        index          Suburb         Address  Rooms Type      Price Method  \
# 13521  13521  Port Melbourne    44 Garton St      4    t  2455000.0     SP
# 13523  13523         Prahran  69 Greville St      4    h  2668000.0      S
# 13553  13553    Surrey Hills    20 Albert Cr      4    h  2720000.0      S
# 13555  13555    Surrey Hills        3 Oak St      4    h  3100000.0     VB
# 13578  13578    Williamstown    96 Verdon St      4    h  2500000.0     PI
#
#         SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 13521  Marshall  26/08/2017       3.5  ...  2.0     123.0           0.0
# 13523    Biggin  26/08/2017       4.6  ...  2.0     383.0         126.0
# 13553       Kay  26/08/2017      10.2  ...  2.0    1005.0         126.0
# 13555  Marshall  26/08/2017      10.2  ...  3.0     832.0         126.0
# 13578   Sweeney  26/08/2017       6.8  ...  5.0     866.0         157.0
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#        index          Suburb               Address  Rooms Type      Price  \
# 80        80     Albert Park  112 Beaconsfield Pde      3    h  2850000.0
# 85        85     Albert Park     104 Richardson St      4    h  2300000.0
# 88        88     Albert Park        29 Faussett St      2    h  2120000.0
# 92        92     Albert Park           2 Dundas Pl      3    h  2615000.0
# 93        93     Albert Park          23 Finlay St      5    h  2100000.0
# ...      ...             ...                   ...    ...  ...        ...
# 13521  13521  Port Melbourne          44 Garton St      4    t  2455000.0
# 13523  13523         Prahran        69 Greville St      4    h  2668000.0
# 13553  13553    Surrey Hills          20 Albert Cr      4    h  2720000.0
# 13555  13555    Surrey Hills              3 Oak St      4    h  3100000.0
# 13578  13578    Williamstown          96 Verdon St      4    h  2500000.0
#
#       Method   SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %%
melb_data[melb_data['Rooms']==3].shape
# Out:
# (5881, 23)

# %%
melb_data[melb_data['Rooms']==3].shape[0]
# Out:
# 5881

# %% [markdown]
# > Условия можно комбинировать, используя операторы & (логическое И) и | (логическое ИЛИ). Условия при этом заключаются в скобки.

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)]
# Out:
#        index         Suburb         Address  Rooms Type     Price Method  \
# 10394  10394         Melton      14 Musk Ct      3    h  295000.0     SP
# 10576  10576  Bacchus Marsh    4 Lidgett St      3    h  285000.0      S
# 13227  13227         Melton  118 Barries Rd      3    h  283000.0      S
#
#              SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 10394  PRDNationwide  27/05/2017      31.7  ...  4.0     600.0        122.86
# 10576          Ryder   8/07/2017      37.5  ...  2.0     612.0        126.00
# 13227             FN  23/09/2017      31.7  ...  0.0     362.0         19.00
#
#        YearBuilt  CouncilArea  Lattitude  Longtitude        Regionname  \
# 10394     1975.0       Melton  -37.68734   144.58001  Western Victoria
# 10576     1970.0    Moorabool  -37.67344   144.43181  Western Victoria
# 13227     1976.0          NaN  -37.68755   144.56887  Western Victoria
#
#        Propertycount           Coordinates
# ...

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea']>100)) & (melb_data['Price']<300000)].shape[0]
# Out:
# 68

# %%
melb_data[melb_data['Type']=='t']['Rooms'].max()
# Out:
# np.int64(5)

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# np.float64(126.0)

# %%
melb_data[melb_data['Bathroom'] == 0].shape
# Out:
# (34, 23)

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape
# Out:
# (5, 23)

# %%
melb_data[melb_data['BuildingArea']==0]['Price'].min()
# Out:
# np.float64(412500.0)

# %%
melb_data[(melb_data['Price']<1000000) & ((melb_data['Rooms']>5) | (melb_data['YearBuilt']>2015))]['Price'].mean()
# Out:
# np.float64(769238.6363636364)

# %%
melb_data[melb_data['YearBuilt']<2015]
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data[(melb_data['Type']=='h') & (melb_data['Price']<3000000)]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
melb_data.columns
# Out:
# Index(['index', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'Coordinates'],
#       dtype='object')
