# %%
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn
# Загрузить стандартный датасет об алмазах из библиотеки Seaborn:
df = sns.load_dataset('diamonds')
print(df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#Удалить часть признаков:
df.drop(['depth', 'table', 'x', 'y', 'z'], axis=1, inplace=True)
print(df)
# Out:
#        carat        cut color clarity  price
# 0       0.23      Ideal     E     SI2    326
# 1       0.21    Premium     E     SI1    326
# 2       0.23       Good     E     VS1    327
# 3       0.29    Premium     I     VS2    334
# 4       0.31       Good     J     SI2    335
# ...      ...        ...   ...     ...    ...
# 53935   0.72      Ideal     D     SI1   2757
# 53936   0.72       Good     D     SI1   2757
# 53937   0.70  Very Good     D     SI1   2757
# 53938   0.86    Premium     H     SI2   2757
# 53939   0.75      Ideal     D     SI2   2757
#
# [53940 rows x 5 columns]

# %%
# Закодируйте категориальные признаки:
df = pd.get_dummies(df, drop_first=True)
print(df)
# Out:
#        carat  price  cut_Premium  cut_Very Good  cut_Good  cut_Fair  color_E  \
# 0       0.23    326        False          False     False     False     True
# 1       0.21    326         True          False     False     False     True
# 2       0.23    327        False          False      True     False     True
# 3       0.29    334         True          False     False     False    False
# 4       0.31    335        False          False      True     False    False
# ...      ...    ...          ...            ...       ...       ...      ...
# 53935   0.72   2757        False          False     False     False    False
# 53936   0.72   2757        False          False      True     False    False
# 53937   0.70   2757        False           True     False     False    False
# 53938   0.86   2757         True          False     False     False    False
# 53939   0.75   2757        False          False     False     False    False
#
#        color_F  color_G  color_H  color_I  color_J  clarity_VVS1  \
# 0        False    False    False    False    False         False
# 1        False    False    False    False    False         False
# 2        False    False    False    False    False         False
# 3        False    False    False     True    False         False
# 4        False    False    False    False     True         False
# ...        ...      ...      ...      ...      ...           ...
# 53935    False    False    False    False    False         False
# 53936    False    False    False    False    False         False
# 53937    False    False    False    False    False         False
# 53938    False    False     True    False    False         False
# 53939    False    False    False    False    False         False
#
#        clarity_VVS2  clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  \
# 0             False        False        False        False         True
# 1             False        False        False         True        False
# 2             False         True        False        False        False
# 3             False        False         True        False        False
# 4             False        False        False        False         True
# ...             ...          ...          ...          ...          ...
# 53935         False        False        False         True        False
# 53936         False        False        False         True        False
# 53937         False        False        False         True        False
# 53938         False        False        False        False         True
# 53939         False        False        False        False         True
#
#        clarity_I1
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 53935       False
# 53936       False
# 53937       False
# 53938       False
# 53939       False
#
# [53940 rows x 19 columns]

# %%
# Логарифмируйте признаки:
df['carat'] = np.log(1+df['carat'])
df['price'] = np.log(1+df['price'])
print(df)
# Out:
#           carat     price  cut_Premium  cut_Very Good  cut_Good  cut_Fair  \
# 0      0.207014  5.789960        False          False     False     False
# 1      0.190620  5.789960         True          False     False     False
# 2      0.207014  5.793014        False          False      True     False
# 3      0.254642  5.814131         True          False     False     False
# 4      0.270027  5.817111        False          False      True     False
# ...         ...       ...          ...            ...       ...       ...
# 53935  0.542324  7.922261        False          False     False     False
# 53936  0.542324  7.922261        False          False      True     False
# 53937  0.530628  7.922261        False           True     False     False
# 53938  0.620576  7.922261         True          False     False     False
# 53939  0.559616  7.922261        False          False     False     False
#
#        color_E  color_F  color_G  color_H  color_I  color_J  clarity_VVS1  \
# 0         True    False    False    False    False    False         False
# 1         True    False    False    False    False    False         False
# 2         True    False    False    False    False    False         False
# 3        False    False    False    False     True    False         False
# 4        False    False    False    False    False     True         False
# ...        ...      ...      ...      ...      ...      ...           ...
# 53935    False    False    False    False    False    False         False
# 53936    False    False    False    False    False    False         False
# 53937    False    False    False    False    False    False         False
# 53938    False    False    False     True    False    False         False
# 53939    False    False    False    False    False    False         False
#
#        clarity_VVS2  clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  \
# 0             False        False        False        False         True
# 1             False        False        False         True        False
# 2             False         True        False        False        False
# 3             False        False         True        False        False
# 4             False        False        False        False         True
# ...             ...          ...          ...          ...          ...
# 53935         False        False        False         True        False
# 53936         False        False        False         True        False
# 53937         False        False        False         True        False
# 53938         False        False        False        False         True
# 53939         False        False        False        False         True
#
#        clarity_I1
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 53935       False
# 53936       False
# 53937       False
# 53938       False
# 53939       False
#
# [53940 rows x 19 columns]

# %%
#Определите целевую переменную и предикторы:
X = df.drop(columns="price")
y = df["price"]
print(X)
print(y)
# Out:
#           carat  cut_Premium  cut_Very Good  cut_Good  cut_Fair  color_E  \
# 0      0.207014        False          False     False     False     True
# 1      0.190620         True          False     False     False     True
# 2      0.207014        False          False      True     False     True
# 3      0.254642         True          False     False     False    False
# 4      0.270027        False          False      True     False    False
# ...         ...          ...            ...       ...       ...      ...
# 53935  0.542324        False          False     False     False    False
# 53936  0.542324        False          False      True     False    False
# 53937  0.530628        False           True     False     False    False
# 53938  0.620576         True          False     False     False    False
# 53939  0.559616        False          False     False     False    False
#
#        color_F  color_G  color_H  color_I  color_J  clarity_VVS1  \
# 0        False    False    False    False    False         False
# 1        False    False    False    False    False         False
# 2        False    False    False    False    False         False
# 3        False    False    False     True    False         False
# 4        False    False    False    False     True         False
# ...        ...      ...      ...      ...      ...           ...
# 53935    False    False    False    False    False         False
# 53936    False    False    False    False    False         False
# 53937    False    False    False    False    False         False
# 53938    False    False     True    False    False         False
# 53939    False    False    False    False    False         False
#
#        clarity_VVS2  clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  \
# 0             False        False        False        False         True
# 1             False        False        False         True        False
# 2             False         True        False        False        False
# 3             False        False         True        False        False
# 4             False        False        False        False         True
# ...             ...          ...          ...          ...          ...
# 53935         False        False        False         True        False
# 53936         False        False        False         True        False
# 53937         False        False        False         True        False
# 53938         False        False        False        False         True
# 53939         False        False        False        False         True
#
#        clarity_I1
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 53935       False
# 53936       False
# 53937       False
# 53938       False
# 53939       False
#
# [53940 rows x 18 columns]
# 0        5.789960
# 1        5.789960
# 2        5.793014
# 3        5.814131
# 4        5.817111
#            ...
# 53935    7.922261
# 53936    7.922261
# 53937    7.922261
# 53938    7.922261
# 53939    7.922261
# Name: price, Length: 53940, dtype: float64
